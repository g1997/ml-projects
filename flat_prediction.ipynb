# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('house.csv')

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1230000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
c=df.drop(['date','id','price','view','yr_built','yr_renovated','zipcode','condition','floors'],axis=1)
for i in c:
    plt.figure()
    sns.scatterplot(df[i],df['price'])

# %%
# displaying bar graph of some categorical features 
b=['view','floors','grade','condition']
for i in b:
    plt.figure()
    sns.countplot(data=df,x=i)

# %%
x=df[['sqft_living']]
y=df['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
lr=LinearRegression()
lr.fit(X_train,y_train)

# %%
def predict_price(area):
    return lr.predict([[area]])[0]

# %%
predict_price(670)

# %%
from flask import Flask,request,render_template

# %%
app = Flask(__name__)
@app.route('/predict',methods=['POST'])
def predict_price():
    if request.method == 'POST':
        area=float(request.form['area'])
        output=lr.predict([[area]])[0]
        return render_template("prices.html",output=output)
if __name__=='__main__':
    app.run()
