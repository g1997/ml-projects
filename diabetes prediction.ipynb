# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('diabetes2.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 6              3       78             50             32       88  31.0
# 7             10      115              0              0        0  35.3
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 10             4      110             92              0        0  37.6
# 11            10      168             74              0        0  38.0
# ...

# %%
#Cheking value counts
for i in df:
    print(i,'->',df[i].value_counts())
    print("\n\n")
# Out:
# Pregnancies -> 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 15      1
# 17      1
# Name: Pregnancies, dtype: int64
#
#
#
# Glucose -> 100    17
# 99     17
# 129    14
# 125    14
# 111    14
# 106    14
# 95     13
# 108    13
# 105    13
# 102    13
# 112    13
# 122    12
# 109    12
# 107    11
# 117    11
# 90     11
# 120    11
# 114    11
# 124    11
# 128    11
# 119    11
# 115    10
# 84     10
# 91      9
# 92      9
# 123     9
# 146     9
# 126     9
# 103     9
# 101     9
#        ..
# 75      2
# 76      2
# 77      2
# 170     2
# 195     2
# 57      2
# 174     2
# 175     2
# 188     2
# 153     2
# 159     2
# 62      1
# 72      1
# 56      1
# 44      1
# 65      1
# 61      1
# 198     1
# 67      1
# 190     1
# 149     1
# 191     1
# 186     1
# 182     1
# 178     1
# 177     1
# 172     1
# 169     1
# 160     1
# ...

# %%
for i in df:
    print(i,'->',df[i].isnull().sum())
    print('\n\n')
# Out:
# Pregnancies -> 0
#
#
#
# Glucose -> 0
#
#
#
# BloodPressure -> 0
#
#
#
# SkinThickness -> 0
#
#
#
# Insulin -> 0
#
#
#
# BMI -> 0
#
#
#
# DiabetesPedigreeFunction -> 0
#
#
#
# Age -> 0
#
#
#
# Outcome -> 0

# %%
#Length  of value counts
for i in df:
    print(i,'->',len(df[i].value_counts()))
    print('\n\n')
# Out:
# Pregnancies -> 17
#
#
#
# Glucose -> 136
#
#
#
# BloodPressure -> 47
#
#
#
# SkinThickness -> 51
#
#
#
# Insulin -> 186
#
#
#
# BMI -> 248
#
#
#
# DiabetesPedigreeFunction -> 517
#
#
#
# Age -> 52
#
#
#
# Outcome -> 2

# %%
#Checking unique values in each column
for i in df:
    print(i,'\n',df[i].unique())
    print('\n\n')
# Out:
# Pregnancies
#  [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]
#
#
#
# Glucose
#  [148  85 183  89 137 116  78 115 197 125 110 168 139 189 166 100 118 107
#  103 126  99 196 119 143 147  97 145 117 109 158  88  92 122 138 102  90
#  111 180 133 106 171 159 146  71 105 101 176 150  73 187  84  44 141 114
#   95 129  79   0  62 131 112 113  74  83 136  80 123  81 134 142 144  93
#  163 151  96 155  76 160 124 162 132 120 173 170 128 108 154  57 156 153
#  188 152 104  87  75 179 130 194 181 135 184 140 177 164  91 165  86 193
#  191 161 167  77 182 157 178  61  98 127  82  72 172  94 175 195  68 186
#  198 121  67 174 199  56 169 149  65 190]
#
#
#
# BloodPressure
#  [ 72  66  64  40  74  50   0  70  96  92  80  60  84  30  88  90  94  76
#   82  75  58  78  68 110  56  62  85  86  48  44  65 108  55 122  54  52
#   98 104  95  46 102 100  61  24  38 106 114]
#
#
#
# SkinThickness
#  [35 29  0 23 32 45 19 47 38 30 41 33 26 15 36 11 31 37 42 25 18 24 39 27
# ...

# %% [markdown]
# # EDA

# %%
## To find out bar plots
plt.figure(figsize=(9,9))
sns.countplot(data=df,x='Outcome',hue='Pregnancies')
plt.show()

# %%
# PLotting scatterplots
for i in df:
    if i!='Outcome':
        sns.scatterplot(df[i],df['Outcome'])
        plt.show()

# %%
for i in df:
    sns.distplot(df[i],bins=15)
    plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X=df.iloc[:,:-1]
Y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
lr=LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr.score(X_test,y_test)
y_pred=lr.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       146
#            1       0.77      0.55      0.64        85
#
#     accuracy                           0.77       231
#    macro avg       0.77      0.73      0.74       231
# weighted avg       0.77      0.77      0.76       231

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bg1=BaggingClassifier(LogisticRegression(),n_estimators=10,max_samples=250,random_state=1,bootstrap=False)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
bg1.fit(X_train,y_train)
# Out:
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
bg1.score(X_test,y_test)
y_pred=lr.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.90      0.84       146
#            1       0.77      0.55      0.64        85
#
#     accuracy                           0.77       231
#    macro avg       0.77      0.73      0.74       231
# weighted avg       0.77      0.77      0.76       231

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

# %%
rus=RandomUnderSampler()

# %%
X_sample1,y_sample1=rus.fit_sample(X_train,y_train)

# %%
lr2=LogisticRegression()

# %%
lr2.fit(X_sample1,y_sample1)
# Out:
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=lr2.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       146
#            1       0.65      0.73      0.69        85
#
#     accuracy                           0.75       231
#    macro avg       0.74      0.75      0.74       231
# weighted avg       0.76      0.75      0.76       231

# %%
X=df.iloc[:,:-2]
Y=df.iloc[:,-1]
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
ros=RandomOverSampler()
X_sample2,y_sample2=ros.fit_sample(X_train,y_train)

# %%
lr3=LogisticRegression(max_iter=200)
lr3.fit(X_sample2,y_sample2)
# Out:
# C:\Users\Ganesh B Kamath\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=200,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred=lr3.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       146
#            1       0.71      0.79      0.74        85
#
#     accuracy                           0.80       231
#    macro avg       0.79      0.80      0.79       231
# weighted avg       0.81      0.80      0.80       231

# %%
lr3.score(X_test,y_test)
# Out:
# 0.8008658008658008

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction
# 0                     0.627
# 1                     0.351
# 2                     0.672
# 3                     0.167
# 4                     2.288

# %%
pr=int(input('Enter pregnancies:' ))
glu=int(input('Enter Glucose:' ))
bp=int(input('Enter Blood Pressure:' ))
skin=int(input('Enter Skin Thickness: '))
skin=int(input('Enter Skin Thickness: '))
ins=int(input('Enter Insulin: '))
bmi=float(input('Enter BMI:'))
diab=float(input('Enter DiabPedigree: '))
outcome=lr3.predict([[pr,glu,bp,skin,ins,bmi,diab]])
if(outcome[0]==1):
    print("The patient has diabetes!!!")
else:
    print('The patient does not have diabetes!!!')
# Out:
# Enter pregnancies:5
# Enter Glucose:147
# Enter Blood Pressure:70
# Enter Skin Thickness: 17
# Enter Skin Thickness: 150
# Enter Insulin: 102
# Enter BMI:20.5
# Enter DiabPedigree: 0.175
# The patient does not have diabetes!!!

# %%
print(outcome[0])
# Out:
# 1
